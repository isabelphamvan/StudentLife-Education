# %%
import pandas as pd

df = pd.read_csv('deadlines.csv')
df_deadlines = df.melt(id_vars='uid', var_name='date', value_name='count')
df_deadlines = df_deadlines[df_deadlines['count'] > 0].reset_index(drop=True)
df_deadlines['date'] = pd.to_datetime(df_deadlines['date'])
df_deadlines
# Out:
# uid       date  count
# u12 2013-03-27    1.0
# u49 2013-03-27    2.0
# u14 2013-03-28    1.0
# u16 2013-03-28    1.0
# u49 2013-03-28    1.0
# u30 2013-03-29    1.0
# u32 2013-03-29    1.0
# u49 2013-03-29    2.0
# u54 2013-03-29    1.0
# u59 2013-03-29    1.0
# u05 2013-03-31    1.0
# u10 2013-03-31    1.0
# u12 2013-03-31    1.0
# u19 2013-03-31    1.0
# u22 2013-03-31    1.0
# u30 2013-03-31    1.0
# u41 2013-03-31    1.0
# u46 2013-03-31    1.0
# u52 2013-03-31    1.0
# u07 2013-04-01    1.0
# u18 2013-04-01    1.0
# u24 2013-04-01    1.0
# u44 2013-04-01    1.0
# u47 2013-04-01    1.0
# u49 2013-04-01    2.0
# u50 2013-04-01    1.0
# u57 2013-04-01    1.0
# u59 2013-04-01    2.0
# u02 2013-04-02    1.0
# u07 2013-04-02    1.0
# u13 2013-04-02    1.0
# u14 2013-04-02    2.0
# u16 2013-04-02    1.0
# u19 2013-04-02    1.0
# u23 2013-04-02    1.0
# u31 2013-04-02    1.0
# u34 2013-04-02    1.0
# u35 2013-04-02    1.0
# u42 2013-04-02    1.0
# u45 2013-04-02    1.0
# ...
